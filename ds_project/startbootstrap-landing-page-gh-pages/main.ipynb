# %% [markdown]
# #### Import packages

# %%
import pandas as pd
import plotly.express as px
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load Dataset

# %%
# I moved the dataset as the same directory as this notebook, so just the file name should be fine : )
df = pd.read_csv('./data/Clean_Dataset-1.csv')

# %%
new = df.sample(frac=0.05, random_state=123)

# %% [markdown]
# #### Data Cleaning

# %%
len(df['flight'].unique())
# Out:
# 1561

# %%
del df['Unnamed: 0'] #Gunnar: This column wasn't necessary
del df['flight']

# %%
df = df.sort_values(by = 'price') #Gunnar: The rows are sorted by cheapest to most expensive

# %%
columnsTitles=['airline', 'source_city', 'destination_city', 'departure_time', 'stops', 'arrival_time', 'class', 'duration', 'days_left',  'Distance (km)', 'price']
df = df.reindex(columns=columnsTitles)
df.head(8)                             #Gunnar: I moved destination_city next to source_city to make it easier to read
# Out:
#     airline source_city destination_city departure_time stops   arrival_time  \
# 0  SpiceJet           1                2        Evening  zero          Night
# 1  SpiceJet           1                2  Early_Morning  zero        Morning
# 2   AirAsia           1                2  Early_Morning  zero  Early_Morning
# 3   Vistara           1                2        Morning  zero      Afternoon
# 4   Vistara           1                2        Morning  zero        Morning
# 5   Vistara           1                2        Morning  zero      Afternoon
# 6   Vistara           1                2        Morning  zero        Morning
# 7   Vistara           1                2      Afternoon  zero        Evening
#
#      class  duration  days_left  Distance (km)  price
# 0  Economy      2.17          1            NaN   5953
# 1  Economy      2.33          1            NaN   5953
# 2  Economy      2.17          1            NaN   5956
# 3  Economy      2.25          1            NaN   5955
# 4  Economy      2.33          1            NaN   5955
# 5  Economy      2.33          1            NaN   5955
# 6  Economy      2.08          1            NaN   6060
# 7  Economy      2.17          1            NaN   6060

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300153 entries, 205012 to 261377
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   source_city       300153 non-null  object
#  2   destination_city  300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   class             300153 non-null  object
#  7   duration          300153 non-null  float64
#  8   days_left         300153 non-null  int64
#  9   Distance (km)     0 non-null       float64
#  10  price             300153 non-null  int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 27.5+ MB

# %%
#Gunnar: This is a long one. It will add a distance column~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
df.loc[df['source_city'] == 'Delhi', 'source_city'] = 1
df.loc[df['source_city'] == 'Mumbai', 'source_city'] = 2
df.loc[df['source_city'] == 'Bangalore', 'source_city'] = 3
df.loc[df['source_city'] == 'Kolkata', 'source_city'] = 4
df.loc[df['source_city'] == 'Hyderabad', 'source_city'] = 5
df.loc[df['source_city'] == 'Chennai', 'source_city'] = 6
df.loc[df['destination_city'] == 'Delhi', 'destination_city'] = 1
df.loc[df['destination_city'] == 'Mumbai', 'destination_city'] = 2
df.loc[df['destination_city'] == 'Bangalore', 'destination_city'] = 3
df.loc[df['destination_city'] == 'Kolkata', 'destination_city'] = 4
df.loc[df['destination_city'] == 'Hyderabad', 'destination_city'] = 5
df.loc[df['destination_city'] == 'Chennai', 'destination_city'] = 6
df['Distance (km)'] = np.where((df['source_city'] == 1) & (df['destination_city'] == 2), 1148, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 2) & (df['destination_city'] == 1), 1148, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 1) & (df['destination_city'] == 3), 1740, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 3) & (df['destination_city'] == 1), 1740, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 1) & (df['destination_city'] == 4), 1305, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 4) & (df['destination_city'] == 1), 1305, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 1) & (df['destination_city'] == 5), 1264, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 5) & (df['destination_city'] == 1), 1264, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 1) & (df['destination_city'] == 6), 1757, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 6) & (df['destination_city'] == 1), 1757, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 2) & (df['destination_city'] == 3), 842, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 3) & (df['destination_city'] == 2), 842, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 2) & (df['destination_city'] == 4), 1652, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 4) & (df['destination_city'] == 2), 1652, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 2) & (df['destination_city'] == 5), 617, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 5) & (df['destination_city'] == 2), 617, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 2) & (df['destination_city'] == 6), 1028, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 6) & (df['destination_city'] == 2), 1028, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 3) & (df['destination_city'] == 4), 1561, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 4) & (df['destination_city'] == 3), 1561, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 3) & (df['destination_city'] == 5), 503, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 5) & (df['destination_city'] == 3), 503, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 3) & (df['destination_city'] == 6), 290, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 6) & (df['destination_city'] == 3), 290, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 4) & (df['destination_city'] == 5), 1180, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 5) & (df['destination_city'] == 4), 1180, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 4) & (df['destination_city'] == 6), 1366, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 6) & (df['destination_city'] == 4), 1366, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 5) & (df['destination_city'] == 6), 507, df['Distance (km)'])
df['Distance (km)'] = np.where((df['source_city'] == 6) & (df['destination_city'] == 5), 507, df['Distance (km)'])
df.loc[df['source_city'] == 1, 'source_city'] = 'Delhi'
df.loc[df['source_city'] == 2, 'source_city'] = 'Mumbai'
df.loc[df['source_city'] == 3, 'source_city'] = 'Bangalore'
df.loc[df['source_city'] == 4, 'source_city'] = 'Kolkata'
df.loc[df['source_city'] == 5, 'source_city'] = 'Hyderabad'
df.loc[df['source_city'] == 6, 'source_city'] = 'Chennai'
df.loc[df['destination_city'] == 1, 'destination_city'] = 'Delhi'
df.loc[df['destination_city'] == 2, 'destination_city'] = 'Mumbai'
df.loc[df['destination_city'] == 3, 'destination_city'] = 'Bangalore'
df.loc[df['destination_city'] == 4, 'destination_city'] = 'Kolkata'
df.loc[df['destination_city'] == 5, 'destination_city'] = 'Hyderabad'
df.loc[df['destination_city'] == 6, 'destination_city'] = 'Chennai'
del df['source_city']
del df['destination_city']
df.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Distance (km)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [43], in <cell line: 14>()
#      12 df.loc[df['destination_city'] == 'Hyderabad', 'destination_city'] = 5
#      13 df.loc[df['destination_city'] == 'Chennai', 'destination_city'] = 6
# ---> 14 df['Distance (km)'] = np.where((df['source_city'] == 1) & (df['destination_city'] == 2), 1148, df['Distance (km)'])
#      15 df['Distance (km)'] = np.where((df['source_city'] == 2) & (df['destination_city'] == 1), 1148, df['Distance (km)'])
#      16 df['Distance (km)'] = np.where((df['source_city'] == 1) & (df['destination_city'] == 3), 1740, df['Distance (km)'])
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Distance (km)'

# %% [markdown]
# #### Exploratory Data Analysis

# %%
#gianna, this graph shows a relation b/w price and days left to buy, this shows how ot could be more or less expensive depending on the day it was purchased
fig4 = px.scatter(new, x="days_left", y="price", hover_name='airline', color="airline", log_x=True, size_max=60) 
fig4.show()
fig4.write_html('days.html')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="ac1b1b61-498a-4328-90e1-9ec0d2a49bcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac1b1b61-498a-4328-90e1-9ec0d2a49bcb")) {                    Plotly.newPlot(                        "ac1b1b61-498a-4328-90e1-9ec0d2a49bcb",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>airline=Vistara<br>days_left=%{x}<br>price=%{y}<extra></extra>","hovertext":["Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara"," ...

# %%
#gianna, scatter plot showing how time of flight could potentially effect the price(ex, fewer late night flight, while evening is more frequent and expensive)
fig8 = px.scatter(new, x="price", y="departure_time", hover_name='airline', color="airline")
fig8.show()
fig8.write_html("takeoff.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="005f80ee-163b-4e73-8a9e-e884a6c5c9a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("005f80ee-163b-4e73-8a9e-e884a6c5c9a2")) {                    Plotly.newPlot(                        "005f80ee-163b-4e73-8a9e-e884a6c5c9a2",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>airline=Vistara<br>price=%{x}<br>departure_time=%{y}<extra></extra>","hovertext":["Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vistara","Vista ...

# %%
fig = px.histogram(new, x='airline', color='class', hover_name="price")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="31dc1934-b49b-4881-9692-10f54c53195c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Vistara","showlegend":true,"x":["Evening","Evening","Early_Morning","Afternoon","Evening","Early_Morning","Night","Night","Afternoon","Night","Morning","Morning","Night","Afternoon","Evening","Early_Morning","Night","Afternoon","Afternoon","Afternoon","Night","Early_Morning","Afternoon","Early_Morning","Early_Morning","Evening","Early_Morning","Afternoon","Evening","Night","Early_Morning","Early_Morning","Morning","Morning","Afternoon","Morning","Morning","Morning","Early_Morning","Early_Morning","Early_Morning","Night","Early_Morning","Evening","Early_Morning","Early_Morning","Night","Morning","Afternoon","Morning","Night","Early_Morning","Afternoon","Early_Morning","Afternoon","Morning","Night","Night","Afternoon","Evening","Morning","Evening","Night","Morning","Morning","Night","Evening","Morning","Morning","Morning","Morning","Night","Night","Early_Morning","Morning","Evening","Night","Early_Morning","Evening","Night","Evening","Morning","Evening","Evening","Night","Early_Morning","Morning","Early_Morning","Morning","Evening","Early_Morning","Morning","Evening","Night","Evening","Night","Morning","Night","Evening","Early_Morning","Night","Morning","Early_Morning","Afternoon","Afternoon","Early_Morning","Morning","Evening","Night","Early_Morning","Night","Morning","Morning","Night","Evening","Early_Morning","Early_Morning","Evening","Early_Morning","Night","Early_Morning","Night","Evening","Afternoon","Morning","Evening","Early_Morning","Afternoon","Evening","Evening","Morning","Night","Afternoon","Morning","Early_Morning","Morning","Early_Morning","Night","Morning","Night","Night","Afternoon","Night","Night","Morning","Morning","Morning","Early_Morning","Early_Morning","Night","Afternoon","Night","Early_Morning","Early_Morning","Early_Morning","Evening","Evening","Morning","Night","Morning","Night","Night","Morning","Afternoon","Afternoon","Early_Morning","Morning","Night","Afternoon","Night","Evening","Early_Morning","Afternoon","Early_Morning","Night","Early_Morning","Night","Early_Morning","Night","Evening","Morning","Morning","Morning","Morning","Afternoon","Evening","Evening","Morning","Night","Night","Night","Early_Morning","Early_Morning","Afternoon","Night","Afternoon","Early_Morning","Early_Morning","Evening","Morning","Early_Morning","Morning","Evening","Early_Morning","Early_Morning","Morning","Afternoon","Night","Afternoon","Night","Early_Morning","Evening","Morning","Morning","Early_Morning","Evening","Morning","Evening","Morning","Early_Morning","Morning","Morning","Early_Morning","Evening","Morning","Afternoon","Morning","Night","Evening","Evening","Evening","Morning","Early_Morning","Morning","Early_Morning","Early_Morning","Morning","Night","Evening","Evening","Morning","Early_Morning","Morning","Early_Morning","Afternoon","Early_Morning","Night","Night","Afternoon","Evening","Morning","Morning","Night","Night","Evening","Morning","Morning","Night","Afternoon","Afternoon","Night","Night","Evening","Night","Early_Morning","Afternoon","Evening","Evening","Night","Evening","Evening","Early_Morning","Evening","Morning","Afternoon","Afternoon","Morning","Evening","Evening","Evening","Early_Morning","Night","Morning","Early_Morning","Morning","Night","Early_Morning","Morning","Early_Morning","Ear ...

# %%
fig2 = px.pie(new, 'airline')
fig2.show() #Gunnar: This graph shows what percentage of the dataset each airline is
#fig.write_html('file_name.html')
#fig2.write_html('airline.html')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="5c36993c-f4aa-4a00-8864-23c7fc3e08ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5
%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["AirAsia","Air_India","GO_FIRST","Indigo","SpiceJet","Vistara"],"xaxis":"x","y":[4091.0727419555224,23507.01911190229,5652.007595045959,5324.216303339517,6179.278881367218,30396.53630170735],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}] ...

# %%
figg = px.bar(avgpr, x = 'airline', y = 'Distance (km)')
figg.show()                           #Gunnar: This shows the average distance each airline flies
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="e620ba8f-555f-4f16-b18b-e3123b24b4c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e620ba8f-555f-4f16-b18b-e3123b24b4c5")) {                    Plotly.newPlot(                        "e620ba8f-555f-4f16-b18b-e3123b24b4c5",                        [{"alignmentgroup":"True","hovertemplate":"airline=%{x}<br>Distance (km)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["AirAsia","Air_India","GO_FIRST","Indigo","SpiceJet","Vistara"],"xaxis":"x","y":[1334.2413343272456,1147.535986253276,1221.228671298494,1202.2786873840446,1466.1316169126624,1128.064039293284],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"typ ...

# %%
 #Gunnar: I made a graph but my computer crashed every time I looked at it so I deleted it. It showed how expensive flights are at different distances. Surprisingly, it doesn't seem to matter. Prices were about the same at every distance.

# %% [markdown]
# ### Convert categorical variables into dummy variables

# %%
feature=['airline', 'departure_time', 'stops', 'arrival_time', 'class']
for col in feature:
    df = pd.concat([df.drop(col, axis=1), pd.get_dummies(df[col], prefix=col, prefix_sep='_')], axis=1)

# %%
cols = df.columns
cols
# Out:
# Index(['source_city', 'destination_city', 'duration', 'days_left', 'price',
#        'airline_AirAsia', 'airline_Air_India', 'airline_GO_FIRST',
#        'airline_Indigo', 'airline_SpiceJet', 'airline_Vistara',
#        'departure_time_Afternoon', 'departure_time_Early_Morning',
#        'departure_time_Evening', 'departure_time_Late_Night',
#        'departure_time_Morning', 'departure_time_Night', 'stops_one',
#        'stops_two_or_more', 'stops_zero', 'arrival_time_Afternoon',
#        'arrival_time_Early_Morning', 'arrival_time_Evening',
#        'arrival_time_Late_Night', 'arrival_time_Morning', 'arrival_time_Night',
#        'class_Business', 'class_Economy'],
#       dtype='object')

# %% [markdown]
# ### Train Test Split

# %%
y = df['price']

X = df.drop("price" , axis = 1)

# %%
X.head()
# Out:
#         duration  days_left  Distance (km)  airline_AirAsia  \
# 205012      4.75         31          507.0                0
# 205754     10.08         39          507.0                0
# 205024      8.83         31          507.0                0
# 204736      1.17         28          507.0                1
# 205023      8.67         31          507.0                0
#
#         airline_Air_India  airline_GO_FIRST  airline_Indigo  airline_SpiceJet  \
# 205012                  0                 0               1                 0
# 205754                  0                 0               1                 0
# 205024                  0                 0               1                 0
# 204736                  0                 0               0                 0
# 205023                  0                 0               1                 0
#
#         airline_Vistara  departure_time_Afternoon  ...  stops_two_or_more  \
# 205012                0                         1  ...                  0
# 205754                0                         1  ...                  0
# 205024                0                         0  ...                  0
# 204736                0                         0  ...                  0
# 205023                0                         1  ...                  0
#
#         stops_zero  arrival_time_Afternoon  arrival_time_Early_Morning  \
# 205012           0                       0                           0
# 205754           0                       0                           0
# 205024           0                       0                           0
# 204736           1                       0                           0
# 205023           0                       0                           0
#
#         arrival_time_Evening  arrival_time_Late_Night  arrival_time_Morning  \
# 205012                     1                        0                     0
# 205754                     0                        0                     0
# 205024                     1                        0                     0
# 204736                     0                        0                     1
# 205023                     0                        0                     0
#
#         arrival_time_Night  class_Business  class_Economy
# 205012                   0               0              1
# 205754                   1               0              1
# 205024                   0               0              1
# 204736                   0               0              1
# 205023                   1               0              1
#
# [5 rows x 26 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=123)

# %%
X_train
# Out:
#         duration  days_left  Distance (km)  airline_AirAsia  \
# 204718      8.42         26          507.0                0
# 41581       9.42         41         1757.0                1
# 203679     15.50         14          507.0                0
# 196853     11.17         39          290.0                0
# 22298      16.92         14         1305.0                0
# ...          ...        ...            ...              ...
# 110177      7.25          6          503.0                0
# 201050      2.33         34         1366.0                1
# 72398      13.92         17          617.0                0
# 254283     12.42         24         1561.0                0
# 270448     22.83          6         1180.0                0
#
#         airline_Air_India  airline_GO_FIRST  airline_Indigo  airline_SpiceJet  \
# 204718                  0                 0               0                 0
# 41581                   0                 0               0                 0
# 203679                  0                 0               0                 0
# 196853                  0                 0               0                 0
# 22298                   0                 0               0                 0
# ...                   ...               ...             ...               ...
# 110177                  1                 0               0                 0
# 201050                  0                 0               0                 0
# 72398                   0                 0               0                 0
# 254283                  0                 0               0                 0
# 270448                  1                 0               0                 0
#
#         airline_Vistara  departure_time_Afternoon  ...  stops_two_or_more  \
# 204718                1                         1  ...                  1
# 41581                 0                         0  ...                  0
# 203679                1                         0  ...                  0
# 196853                1                         0  ...                  0
# 22298                 1                         0  ...                  0
# ...                 ...                       ...  ...                ...
# 110177                0                         1  ...                  0
# 201050                0                         0  ...                  0
# 72398                 1                         0  ...                  0
# 254283                1                         0  ...                  0
# 270448                0                         0  ...                  0
#
#         stops_zero  arrival_time_Afternoon  arrival_time_Early_Morning  \
# 204718           0                       0                           0
# 41581            0                       0                           0
# 203679           0                       1                           0
# 196853           0                       0                           0
# 22298            0                       0                           0
# ...            ...                     ...                         ...
# 110177           0                       0                           0
# 201050           1                       1                           0
# 72398            0                       0                           0
# 254283           0                       0                           0
# 270448           0                       0                           0
#
#         arrival_time_Evening  arrival_time_Late_Night  arrival_time_Morning  \
# 204718                     0                        0                     0
# 41581                      1                        0                     0
# 203679                     0                        0                     0
# 196853                     0                        0                     0
# 22298                      0                        0                     1
# ...                      ...                      ...                   ...
# 110177                     0                        0                     0
# 201050                     0                        0                     0
# 72398                      0                        0                     1
# 254283                     0                        0                     1
# 270448                     1                        0                     0
#
#         arrival_time_Night  class_Business  class_Economy
# 204718                   1               0              1
# 41581                    0               0              1
# 203679                   0               0              1
# 196853                   1               0              1
# 22298                    0               0              1
# ...                    ...             ...            ...
# 110177                   1               0              1
# 201050                   0               0              1
# 72398                    0               0              1
# 254283                   0               1              0
# 270448                   0               1              0
#
# [240122 rows x 26 columns]

# %%
y_train
# Out:
# 204718     6032
# 41581      1998
# 203679    11069
# 196853     4755
# 22298     11389
#           ...
# 110177    13054
# 201050     2672
# 72398      3334
# 254283    60508
# 270448    52063
# Name: price, Length: 240122, dtype: int64

# %%
X_test
# Out:
#         duration  days_left  Distance (km)  airline_AirAsia  \
# 247388      5.00         34         1740.0                0
# 57761       5.50         29          842.0                0
# 89314       9.42         27         1740.0                0
# 222793     23.25         16         1757.0                0
# 84235       5.08          2         1740.0                0
# ...          ...        ...            ...              ...
# 5180       14.08         27         1148.0                1
# 45592      24.67         15         1148.0                0
# 28383       7.42         47         1305.0                0
# 165031     17.42         45          617.0                0
# 137306      6.50         15         1561.0                0
#
#         airline_Air_India  airline_GO_FIRST  airline_Indigo  airline_SpiceJet  \
# 247388                  0                 0               0                 0
# 57761                   0                 1               0                 0
# 89314                   0                 0               1                 0
# 222793                  0                 0               0                 0
# 84235                   0                 0               1                 0
# ...                   ...               ...             ...               ...
# 5180                    0                 0               0                 0
# 45592                   1                 0               0                 0
# 28383                   0                 0               0                 0
# 165031                  1                 0               0                 0
# 137306                  0                 0               1                 0
#
#         airline_Vistara  departure_time_Afternoon  ...  stops_two_or_more  \
# 247388                1                         0  ...                  0
# 57761                 0                         0  ...                  0
# 89314                 0                         0  ...                  0
# 222793                1                         0  ...                  0
# 84235                 0                         1  ...                  0
# ...                 ...                       ...  ...                ...
# 5180                  0                         1  ...                  0
# 45592                 0                         0  ...                  0
# 28383                 1                         0  ...                  0
# 165031                0                         0  ...                  0
# 137306                0                         0  ...                  0
#
#         stops_zero  arrival_time_Afternoon  arrival_time_Early_Morning  \
# 247388           0                       1                           0
# 57761            0                       0                           0
# 89314            0                       0                           0
# 222793           0                       0                           0
# 84235            0                       0                           0
# ...            ...                     ...                         ...
# 5180             0                       0                           0
# 45592            0                       0                           1
# 28383            0                       0                           0
# 165031           0                       0                           0
# 137306           0                       1                           0
#
#         arrival_time_Evening  arrival_time_Late_Night  arrival_time_Morning  \
# 247388                     0                        0                     0
# 57761                      0                        0                     0
# 89314                      0                        0                     1
# 222793                     1                        0                     0
# 84235                      0                        0                     0
# ...                      ...                      ...                   ...
# 5180                       0                        1                     0
# 45592                      0                        0                     0
# 28383                      1                        0                     0
# 165031                     0                        0                     1
# 137306                     0                        0                     0
#
#         arrival_time_Night  class_Business  class_Economy
# 247388                   0               1              0
# 57761                    1               0              1
# 89314                    0               0              1
# 222793                   0               1              0
# 84235                    1               0              1
# ...                    ...             ...            ...
# 5180                     0               0              1
# 45592                    0               0              1
# 28383                    0               0              1
# 165031                   0               0              1
# 137306                   0               0              1
#
# [60031 rows x 26 columns]

# %%
y_test
# Out:
# 247388    42521
# 57761      5102
# 89314      5563
# 222793    45672
# 84235     12528
#           ...
# 5180       3733
# 45592      8444
# 28383      6821
# 165031     6467
# 137306     6489
# Name: price, Length: 60031, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import numpy as np

# %%
del new['Unnamed: 0']

# %%
sns.heatmap(df.corr())
heat = sns.heatmap(df.corr())

# %% [markdown]
# ### Model Fitting

# %% [markdown]
# ##### Linear Regression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.9076584221540005

# %%
prediction = lr.predict(X_test)

# %%
np.mean(abs(y_test - prediction))
# Out:
# 4626.5004532039675

# %%
y_test[1:5]
# Out:
# 57761      5102
# 89314      5563
# 222793    45672
# 84235     12528
# Name: price, dtype: int64

# %%
prediction[1:5]
# Out:
# array([ 6668.34175086,  7855.33995932, 57280.9384487 , 10653.02058781])

# %%
predictio = lr.predict(X_test)

# %%
plt.scatter(y_test,predictio, s=0.1, c='red')
plt.xlabel('Price', fontsize = 30)
plt.ylabel('Estimate', fontsize = 30)
plt.grid('on')
plt.plot([0,120000], [0,120000])
plt.show()

# %% [markdown]
# ### Support Vector Machines
#
# Support vector regression

# %%
from sklearn.svm import SVR

# %%
#todo Riley and Nathan! sent some tips in zoom chat :)
svm = SVR(kernel='rbf')

# %%
svm.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 svm.fit(X_train, y_train)
#
# File ~/miniconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:251, in BaseLibSVM.fit(self, X, y, sample_weight)
#     248     print("[LibSVM]", end="")
#     250 seed = rnd.randint(np.iinfo("i").max)
# --> 251 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     252 # see comment on the other call to np.iinfo in this file
#     254 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~/miniconda3/lib/python3.9/site-packages/sklearn/svm/_base.py:333, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     319 libsvm.set_verbosity_wrap(self.verbose)
#     321 # we don't pass **self.get_params() to allow subclasses to
#     322 # add other parameters to __init__
#     323 (
#     324     self.support_,
#     325     self.support_vectors_,
#     326     self._n_support,
#     327     self.dual_coef_,
#     328     self.intercept_,
#     329     self._probA,
#     330     self._probB,
#     331     self.fit_status_,
#     332     self._num_iter,
# --> 333 ) = libsvm.fit(
#     334     X,
#     335     y,
#     336     svm_type=solver_type,
#     337     sample_weight=sample_weight,
#     338     class_weight=self.class_weight_,
#     339     kernel=kernel,
#     340     C=self.C,
#     341     nu=self.nu,
#     342     probability=self.probability,
#     343     degree=self.degree,
#     344     shrinking=self.shrinking,
#     345     tol=self.tol,
#     346     cache_size=self.cache_size,
#     347     coef0=self.coef0,
#     348     gamma=self._gamma,
#     349     epsilon=self.epsilon,
#     350     max_iter=self.max_iter,
#     351     random_seed=random_seed,
#     352 )
#     354 self._warn_from_fit_status()
#
# File sklearn/svm/_libsvm.pyx:237, in sklearn.svm._libsvm.fit()
#
# KeyboardInterrupt:

# %%
svm.score(X_test, y_test)

# %%
prediction = svm.predict(X_test)
np.mean(abs(y_test - prediction))

# %%
y_test[:11]

# %%
prediction[:11]

# %% [markdown]
# ##### Random Forest

# %%
rf = RandomForestRegressor(n_estimators=200, criterion='absolute_error', ccp_alpha=0.5)

# %%
distance_train = X_train['Distance (km)'].to_numpy()
distance_test = X_test['Distance (km)'].to_numpy()
distance_train = distance_train.reshape(-1, 1)
distance_test = distance_test.reshape(-1, 1)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(ccp_alpha=0.5, criterion='absolute_error',
#                       n_estimators=200)

# %%
rf.score(X_test, y_test)
# Out:
# 0.9780270990845933

# %%
drf = RandomForestRegressor()

# %%
drf.fit(distance_train, y_train)
# Out:
# RandomForestRegressor()

# %%
predictio = rf.predict(X_test)

# %%
plt.scatter(y_test,predictio, s=0.1, c='red')
plt.xlabel('Price', fontsize = 30)
plt.ylabel('Estimate', fontsize = 30)
plt.grid('on')
plt.plot([0,120000], [0,120000])
plt.show()

# %%
np.mean(abs(y_test - predictio))
# Out:
# 1691.6229291115917

# %% [markdown]
# #### Polynomial or ridge
#
# - Define the model
# - Fit on train data \(X\_train , y\_train\)
# - Score on Train data and test data

# %%
from sklearn.linear_model import Ridge

# %%
rdg = Ridge()

# %%
# n_samples, n_features = 10, 5
# rng = np.random.RandomState(0)
# y = rng.randn(n_samples)
# X = rng.randn(n_samples, n_features)
# clf = Ridge(alpha=1.0)
# clf.fit(X, y)
# Ridge()

# %%
rdg.fit(X_train , y_train) ## this is the part where model trains
# Out:
# Ridge()

# %%
rdg.score(X_train, y_train)
# Out:
# 0.90693679669074

# %%
rdg.score(X_test, y_test)
# Out:
# 0.9072034652577713

# %%
X_test.iloc[0:1,:]
# Out:
#        duration  days_left  Distance (km)  airline_AirAsia  airline_Air_India  \
# 88657      9.67         24         1740.0                0                  0
#
#        airline_GO_FIRST  airline_Indigo  airline_SpiceJet  airline_Vistara  \
# 88657                 0               1                 0                0
#
#        departure_time_Afternoon  ...  stops_two_or_more  stops_zero  \
# 88657                         0  ...                  0           0
#
#        arrival_time_Afternoon  arrival_time_Early_Morning  \
# 88657                       0                           0
#
#        arrival_time_Evening  arrival_time_Late_Night  arrival_time_Morning  \
# 88657                     0                        0                     0
#
#        arrival_time_Night  class_Business  class_Economy
# 88657                   1               0              1
#
# [1 rows x 26 columns]

# %%
rdg.predict(X_test.iloc[0:1,:])
# Out:
# array([8839.80539112])

# %%
## MLP classifier

# %% [markdown]
# ### MLP Regressor

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_regression

# %%
mc = MLPRegressor(hidden_layer_sizes=(100,),max_iter=200)
# recommend setting max_iter=300
#todo hidden_layer_sizes=(100,)

# %%
new = df.sample(frac=0.1, random_state=123)
y = new['price']
X = new.drop("price" , axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=123)

# %%
#X, y = make_classification(n_samples=100, random_state=1)
#X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y,
#...                                                     random_state=1)
#clf = MLPClassifier(hidden_layer_sizes=(100,), random_state=1, max_iter=300).fit(X_train, y_train)
#clf.predict_proba(X_test[:1])
#array([[0.038..., 0.961...]])
#clf.predict(X_test[:5, :])
#array([1, 0, 1, 0, 1])
#clf.score(X_test, y_test)
#0.8...

# %%
mc.fit(X_train, y_train)
# Out:
# /projects/7b851546-01cd-4477-a30c-927567abb7ed/miniconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPRegressor()

# %%
mc.score(X_train, y_train)
# Out:
# 0.8188654499825448

# %%
mc.score(X_test, y_test)
# Out:
# 0.8195802715997837

# %%
prediction = mc.predict(X_test)

# %%
np.mean(abs(y_test - prediction))
# Out:
# 7315.147429707546

# %%
y_test[1:5]
# Out:
# 225871    22140
# 214826    57017
# 65144      5502
# 34319      6569
# Name: price, dtype: int64

# %%
prediction[1:5]
# Out:
# array([30816.05291569, 47521.73412156, 11843.8881664 , 12606.63812034])
