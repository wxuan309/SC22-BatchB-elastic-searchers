# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %%
planedata = pd.read_csv('./Clean_Dataset[1].csv')

# %%
planedata.head()
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# 2  Early_Morning           Mumbai  Economy      2.17          1   5956
# 3      Afternoon           Mumbai  Economy      2.25          1   5955
# 4        Morning           Mumbai  Economy      2.33          1   5955

# %%
planedata.tail()
# Out:
#         Unnamed: 0  airline  flight source_city departure_time stops  \
# 300148      300148  Vistara  UK-822     Chennai        Morning   one
# 300149      300149  Vistara  UK-826     Chennai      Afternoon   one
# 300150      300150  Vistara  UK-832     Chennai  Early_Morning   one
# 300151      300151  Vistara  UK-828     Chennai  Early_Morning   one
# 300152      300152  Vistara  UK-822     Chennai        Morning   one
#
#        arrival_time destination_city     class  duration  days_left  price
# 300148      Evening        Hyderabad  Business     10.08         49  69265
# 300149        Night        Hyderabad  Business     10.42         49  77105
# 300150        Night        Hyderabad  Business     13.83         49  79099
# 300151      Evening        Hyderabad  Business     10.00         49  81585
# 300152      Evening        Hyderabad  Business     10.08         49  81585

# %%
del planedata['Unnamed: 0']

# %%
planedata.head()
# Out:
#     airline   flight source_city departure_time stops   arrival_time  \
# 0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
planedata = planedata.sort_values(by = 'price')

# %%
planedata.tail() # Vistara is consistently expensive
# Out:
#         airline  flight source_city departure_time        stops arrival_time  \
# 270999  Vistara  UK-772     Kolkata        Morning          one      Evening
# 277345  Vistara  UK-870   Hyderabad          Night          one    Afternoon
# 215859  Vistara  UK-809       Delhi        Evening  two_or_more      Evening
# 216096  Vistara  UK-811       Delhi  Early_Morning  two_or_more      Evening
# 261377  Vistara  UK-772     Kolkata        Morning          one        Night
#
#        destination_city     class  duration  days_left   price
# 270999        Hyderabad  Business      9.50         17  114705
# 277345           Mumbai  Business     16.42          3  115211
# 215859          Kolkata  Business     21.08          1  116562
# 216096          Kolkata  Business     10.92          5  117307
# 261377            Delhi  Business     13.50          3  123071

# %%
planedata.head(20) # Indigo is consistantly cheap
# Out:
#          airline   flight source_city departure_time stops arrival_time  \
# 205012    Indigo   6E-605     Chennai      Afternoon   one      Evening
# 205754    Indigo   6E-605     Chennai      Afternoon   one        Night
# 205024    Indigo  6E-6137     Chennai        Morning   one      Evening
# 204736   AirAsia   I5-517     Chennai        Morning  zero      Morning
# 205023    Indigo  6E-6113     Chennai      Afternoon   one        Night
# 203908   AirAsia   I5-517     Chennai        Morning  zero      Morning
# 205022    Indigo   6E-605     Chennai      Afternoon   one        Night
# 205021    Indigo  6E-7185     Chennai        Morning   one      Evening
# 206352  GO_FIRST   G8-504     Chennai      Afternoon  zero    Afternoon
# 206353   AirAsia   I5-517     Chennai        Morning  zero      Morning
# 206354    Indigo  6E-7261     Chennai        Morning   one    Afternoon
# 206355    Indigo  6E-7252     Chennai        Evening   one        Night
# ...

# %%
indigodata = planedata.loc[planedata['airline'] == 'Indigo']
indigodata.tail(10)
# Out:
#        airline   flight source_city departure_time        stops arrival_time  \
# 119780  Indigo  6E-6785     Kolkata        Morning          one    Afternoon
# 104634  Indigo   6E-897   Bangalore        Morning          one        Night
# 61737   Indigo  6E-5332      Mumbai  Early_Morning          one    Afternoon
# 20963   Indigo  6E-2089       Delhi        Morning          one      Evening
# 102914  Indigo   6E-457   Bangalore  Early_Morning  two_or_more    Afternoon
# 119781  Indigo   6E-634     Kolkata        Morning          one        Night
# 20233   Indigo  6E-2329       Delhi        Morning          one      Evening
# 22554   Indigo  6E-2089       Delhi        Morning          one      Evening
# 119782  Indigo  6E-6749     Kolkata        Morning          one      Evening
# 120035  Indigo   6E-634     Kolkata        Morning          one        Night
#
#        destination_city    class  duration  days_left  price
# 119780            Delhi  Economy      6.67          1  28382
# ...

# %%
# FIND A WAY TO DROP SOURCE/DESTINATION CITIES AND REPLACE THEM WITH A DISTANCE COLUMN

# %%
planedata.destination_city.unique()
# Out:
# array(['Hyderabad', 'Bangalore', 'Chennai', 'Mumbai', 'Delhi', 'Kolkata'],
#       dtype=object)

# %%
planedata.source_city.unique()
# Out:
# array(['Chennai', 'Hyderabad', 'Bangalore', 'Mumbai', 'Delhi', 'Kolkata'],
#       dtype=object)

# %%
# Start by adding a distance column DONE~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
header_list = ['airline', 'flight', 'source_city', 'departure_time', 'stops', 'arrival_time', 'destination_city', 'class', 'duration', 'days_left', 'price', 'Distance']
planedata = planedata.reindex(columns = header_list)

# %%
planedata.head(2)
# Out:
#        airline  flight source_city departure_time stops arrival_time  \
# 205012  Indigo  6E-605     Chennai      Afternoon   one      Evening
# 205754  Indigo  6E-605     Chennai      Afternoon   one        Night
#
#        destination_city    class  duration  days_left  price  Distance
# 205012        Hyderabad  Economy      4.75         31   1105       NaN
# 205754        Hyderabad  Economy     10.08         39   1105       NaN

# %%
# TO-DO

# %%
# SWAP departure_time AND destination_city DONE~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
columnsTitles=['airline', 'flight', 'source_city', 'destination_city', 'departure_time', 'stops', 'arrival_time', 'class', 'duration', 'days_left', 'Distance (km)', 'price']
planedata = planedata.reindex(columns=columnsTitles)
planedata.head(1)
# Out:
#        airline  flight source_city destination_city departure_time stops  \
# 205012  Indigo  6E-605     Chennai        Hyderabad      Afternoon   one
#
#        arrival_time    class  duration  days_left  Distance (km)  price
# 205012      Evening  Economy      4.75         31            NaN   1105

# %%
# FIND EVERY COMBINATION OF CITIES

# %%
# FIND THE DISTANCE FOR EACH COMBINATION

# %%
# ADD DISTANCE TO DATASET ----USE IF LOOPS!!!----

# %% [markdown]
# \*All units in km\*
#
# Mumbai = \[Delhi 1148, Bangalore 842, Kolkata 1652, Hyderabad 617, Chennai 1028\]
#
# Bangalore
# = \[Delhi 1740, Mumbai 845, Kolkata 1561, Hyderabad 503, Chennai 290\]
#
# Kolkata = \[Delhi 1305, Mumbai 1652, Bangalore 1560, Hyderabad 1180, Chennai 1366\]
#
# Hyderabad = \[Chennai 507, Delhi 1264, Kolkata 1209, Bangalore 503, Mumbai 617\]
#
# Chennai = \[Hyderabad 507, Mumbai 1028, Bangalore 290, Delhi 1757, Kolkata 1366\]
#
# Delhi = \[Hyderabad 1264, Mumbai 1148, Chennai 1757, Kolkata 1305, Bangalore
# 1740\]

# %%
#I think we can use the loc function for this
#https://www.geeksforgeeks.org/how-to-replace-values-in-column-based-on-condition-in-pandas/

# %%
test_sample = planedata.sample(frac = 0.01)
test_sample['Distance (km)'] = 0
test_sample.head()
# Out:
#           airline   flight source_city destination_city departure_time stops  \
# 38065     Vistara   UK-933       Delhi          Chennai      Afternoon   one
# 264131  Air_India   AI-402     Kolkata           Mumbai        Morning   one
# 64767    GO_FIRST  G8-7545      Mumbai          Kolkata      Afternoon   one
# 193840    Vistara   UK-832     Chennai           Mumbai  Early_Morning   one
# 59129     Vistara   UK-910      Mumbai        Bangalore        Evening   one
#
#        arrival_time     class  duration  days_left  Distance (km)  price
# 38065       Morning   Economy     17.33         20              0   4979
# 264131      Evening  Business      7.58          5              0  50271
# 64767       Evening   Economy      5.50         20              0   5415
# 193840        Night   Economy     14.75         49              0   8233
# 59129         Night   Economy      5.75         36              0   7135

# %%
#Rename cities to number values
test_sample.loc[test_sample['source_city'] == 'Delhi', 'source_city'] = 1
test_sample.loc[test_sample['source_city'] == 'Mumbai', 'source_city'] = 2
test_sample.loc[test_sample['source_city'] == 'Bangalore', 'source_city'] = 3
test_sample.loc[test_sample['source_city'] == 'Kolkata', 'source_city'] = 4
test_sample.loc[test_sample['source_city'] == 'Hyderabad', 'source_city'] = 5
test_sample.loc[test_sample['source_city'] == 'Chennai', 'source_city'] = 6
test_sample.loc[test_sample['destination_city'] == 'Delhi', 'destination_city'] = 1
test_sample.loc[test_sample['destination_city'] == 'Mumbai', 'destination_city'] = 2
test_sample.loc[test_sample['destination_city'] == 'Bangalore', 'destination_city'] = 3
test_sample.loc[test_sample['destination_city'] == 'Kolkata', 'destination_city'] = 4
test_sample.loc[test_sample['destination_city'] == 'Hyderabad', 'destination_city'] = 5
test_sample.loc[test_sample['destination_city'] == 'Chennai', 'destination_city'] = 6
test_sample.head(2)
# Out:
#           airline  flight source_city destination_city departure_time stops  \
# 38065     Vistara  UK-933           1                6      Afternoon   one
# 264131  Air_India  AI-402           4                2        Morning   one
#
#        arrival_time     class  duration  days_left  Distance (km)  price
# 38065       Morning   Economy     17.33         20              0   4979
# 264131      Evening  Business      7.58          5              0  50271

# %%
# GUNNAR!!! the code below works!
# I used the np.where function
# https://numpy.org/doc/stable/reference/generated/numpy.where.html#numpy.where

# %%
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 1) & (test_sample['destination_city'] == 2), 1148, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 2) & (test_sample['destination_city'] == 1), 1148, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 1) & (test_sample['destination_city'] == 3), 1740, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 3) & (test_sample['destination_city'] == 1), 1740, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 1) & (test_sample['destination_city'] == 4), 1305, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 4) & (test_sample['destination_city'] == 1), 1305, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 1) & (test_sample['destination_city'] == 5), 1264, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 5) & (test_sample['destination_city'] == 1), 1264, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 1) & (test_sample['destination_city'] == 6), 1757, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 6) & (test_sample['destination_city'] == 1), 1757, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 2) & (test_sample['destination_city'] == 3), 842, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 3) & (test_sample['destination_city'] == 2), 842, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 2) & (test_sample['destination_city'] == 4), 1652, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 4) & (test_sample['destination_city'] == 2), 1652, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 2) & (test_sample['destination_city'] == 5), 617, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 5) & (test_sample['destination_city'] == 2), 617, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 2) & (test_sample['destination_city'] == 6), 1028, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 6) & (test_sample['destination_city'] == 2), 1028, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 3) & (test_sample['destination_city'] == 4), 1561, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 4) & (test_sample['destination_city'] == 3), 1561, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 3) & (test_sample['destination_city'] == 5), 503, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 5) & (test_sample['destination_city'] == 3), 503, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 3) & (test_sample['destination_city'] == 6), 290, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 6) & (test_sample['destination_city'] == 3), 290, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 4) & (test_sample['destination_city'] == 5), 1180, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 5) & (test_sample['destination_city'] == 4), 1180, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 4) & (test_sample['destination_city'] == 6), 1366, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 6) & (test_sample['destination_city'] == 4), 1366, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 5) & (test_sample['destination_city'] == 6), 507, test_sample['Distance (km)'])
test_sample['Distance (km)'] = np.where((test_sample['source_city'] == 6) & (test_sample['destination_city'] == 5), 507, test_sample['Distance (km)'])

# %%
test_sample.head()
# Out:
#           airline   flight source_city destination_city departure_time stops  \
# 38065     Vistara   UK-933           1                6      Afternoon   one
# 264131  Air_India   AI-402           4                2        Morning   one
# 64767    GO_FIRST  G8-7545           2                4      Afternoon   one
# 193840    Vistara   UK-832           6                2  Early_Morning   one
# 59129     Vistara   UK-910           2                3        Evening   one
#
#        arrival_time     class  duration  days_left  Distance (km)  price
# 38065       Morning   Economy     17.33         20           1757   4979
# 264131      Evening  Business      7.58          5           1652  50271
# 64767       Evening   Economy      5.50         20           1652   5415
# 193840        Night   Economy     14.75         49           1028   8233
# 59129         Night   Economy      5.75         36            842   7135

# %%
# Graphs

# %%
sample = planedata.sample(frac=0.05, random_state=123)
fig = px.scatter(sample, x='airline', y = 'price')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2 = px.pie(sample, 'airline')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig3 = px.scatter(sample, x='source_city', y='destination_city')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig4 = px.pie(sample, 'Distance (km)')
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Random Forest tests because they slow down the main notebook
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
y = df['price']
X = df.drop("price" , axis = 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=123)

# %%
feature=['airline', 'source_city', 'destination_city', 'departure_time', 'stops', 'arrival_time', 'class']
for col in feature:
    df = pd.concat([planedata.drop(col, axis=1), pd.get_dummies(planedata[col], prefix=col, prefix_sep='_')], axis=1)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 df.drop['flight']
#
# TypeError: 'method' object is not subscriptable

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 rf.fit(X_train, y_train)
#
# File ~/miniconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:331, in BaseForest.fit(self, X, y, sample_weight)
#     329 if issparse(y):
#     330     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331 X, y = self._validate_data(
#     332     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333 )
#     334 if sample_weight is not None:
#     335     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~/miniconda3/lib/python3.9/site-packages/sklearn/base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# ...
